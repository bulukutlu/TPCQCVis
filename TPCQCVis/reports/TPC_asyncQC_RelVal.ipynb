# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#1--PilotBeam-2021-apass4-vs-apass5" data-toc-modified-id="1--PilotBeam-2021-apass4-vs-apass5-1">1- PilotBeam 2021 apass4 vs apass5</a></span><ul class="toc-item"><li><span><a href="#QC-tasks-being-compared" data-toc-modified-id="QC-tasks-being-compared-1.1">QC tasks being compared</a></span></li><li><span><a href="#Overview:" data-toc-modified-id="Overview:-1.2">Overview:</a></span><ul class="toc-item"><li><span><a href="#Summary-figure:" data-toc-modified-id="Summary-figure:-1.2.1">Summary figure:</a></span></li></ul></li><li><span><a href="#Bin_count-comparison" data-toc-modified-id="Bin_count-comparison-1.3">Bin_count comparison</a></span></li></ul></li><li><span><a href="#Overlay-Plots-of-problematic-objects" data-toc-modified-id="Overlay-Plots-of-problematic-objects-2">Overlay Plots of problematic objects</a></span></li><li><span><a href="#2--PilotBeam-2021-apass4-vs-LHC22c5-MC" data-toc-modified-id="2--PilotBeam-2021-apass4-vs-LHC22c5-MC-3">2- PilotBeam 2021 apass4 vs LHC22c5 MC</a></span><ul class="toc-item"><li><span><a href="#QC-tasks-being-compared" data-toc-modified-id="QC-tasks-being-compared-3.1">QC tasks being compared</a></span></li><li><span><a href="#Overview:" data-toc-modified-id="Overview:-3.2">Overview:</a></span><ul class="toc-item"><li><span><a href="#Summary-figure:" data-toc-modified-id="Summary-figure:-3.2.1">Summary figure:</a></span></li></ul></li><li><span><a href="#chi2-comparison" data-toc-modified-id="chi2-comparison-3.3">chi2 comparison</a></span></li><li><span><a href="#Cosmics-can-be-seen-but-didn't-lead-to-error" data-toc-modified-id="Cosmics-can-be-seen-but-didn't-lead-to-error-3.4">Cosmics can be seen but didn't lead to error</a></span></li></ul></li></ul></div>

# %%
from IPython.display import display, Markdown, HTML, Image

# %%
display(HTML("<style>.container { width:90% !important; }</style>"))
display(HTML("<style>table {float:left;}</style>"))

# %% [markdown]
# # Using RelVal to compare TPC asyncQC outputs
#
# ## 1- PilotBeam 2021 apass4 vs apass5
# ### QC tasks being compared
# + Tracks
# + PID
#
# ### Overview:
# + Discrapencies observed by Relval in bin_count & num_entries
#   + Looking at the objects the differences don't strik to be too critical

# %% [markdown]
# ---
#
# #### Summary figure:
# ![SummaryTests.png](attachment:SummaryTests.png)

# %% [markdown]
# ---
# ### Bin_count comparison
# Problematic objects:
# + PID_hNClustersBeforeCuts
# + PID_hdEdxEles
# + PID_hdEdxMax
# + PID_hdEdxTot
# + Tracks_hEtaBeforeCuts
# + Tracks_hNClustersBeforeCuts
# + Tracks_hPtRatio
#
# ![test_values_thresholds_test_bin_cont.png](attachment:test_values_thresholds_test_bin_cont.png)

# %% [markdown]
# ---
#
# ## Overlay Plots of problematic objects

# %% [markdown]
# ---
# + PID_hNClustersBeforeCuts
# + Tracks_hNClustersBeforeCuts

# %%
dir = '/home/berki/alice/data/relval/TPC_cmp_apass4_apass5/overlayPlots/'
display(Image(filename=dir+'PIDQC_hNClustersBeforeCuts.png'),
        Image(filename=dir+'TracksQC_hNClustersBeforeCuts.png'))

# %% [markdown]
# ---
# + PID_hdEdxEles
# + PID_hdEdxMax
# + PID_hdEdxTot

# %%
display(Image(filename=dir+'PIDQC_hdEdxEles.png'),
        Image(filename=dir+'PIDQC_hdEdxMax.png'),
        Image(filename=dir+'PIDQC_hdEdxTot.png'),)

# %% [markdown]
# ---
# + Tracks_hEtaBeforeCuts

# %%
display(Image(filename=dir+'TracksQC_hEtaBeforeCuts.png'))

# %% [markdown]
# ---
# + Tracks_hPtRatio

# %%
display(Image(filename=dir+'TracksQC_hPtRatio.png'))

# %% [markdown]
# ---
# ---
#
# ## 2- PilotBeam 2021 apass4 vs LHC22c5 MC
# ### QC tasks being compared
# + Tracks
# + PID
#
# ### Overview:
# + Since histograms not normalized ignoring results of test_bin_count and test_num_entries

# %%
dir = '/home/berki/alice/data/relval/TPC_cmp_apass4_MC/overlayPlots/'

# %% [markdown]
# ---
#
# #### Summary figure:
# ![SummaryTests.png](attachment:SummaryTests.png)

# %% [markdown]
# ---
# ### chi2 comparison
# Problematic objects:
# + PID_hdEdxEles
# + PID_dEdxVsPhiElesAside
# + PID_dEdxVsPhiElesCside
# + PID_ dEdxVsp
# + PID_ dEdxVspBeforeCuts
# + Tracks_hNClustersAfterCuts
# + Tracks_hNClustersBeforeCuts
# + Tracks_hPt
# + Tracks_hPtNeg
# + Tracks_hPtPos
# + Tracks_hPtRatio

# %% [markdown]
# ---
# + PID_hdEdxEles
# + PID_dEdxVsPhiElesAside
# + PID_dEdxVsPhiElesCside

# %%
display(Image(filename=dir+'PIDQC_hdEdxEles.png'),Image(filename=dir+'PIDQC_hdEdxVsPhiElesAside.png'),Image(filename=dir+'PIDQC_hdEdxVsPhiElesCside.png'))

# %% [markdown]
# + PID_hdEdxVsp
# + PID_hdEdxVspBeforeCuts

# %%
display(Image(filename=dir+'PIDQC_hdEdxVsp.png'),Image(filename=dir+'PIDQC_hdEdxVspBeforeCuts.png'))

# %% [markdown]
# + Tracks_hNClustersAfterCuts
# + Tracks_hNClustersBeforeCuts

# %%
display(Image(filename=dir+'TracksQC_hNClustersAfterCuts.png'),Image(filename=dir+'TracksQC_hNClustersBeforeCuts.png'))

# %% [markdown]
# Tracks_hPt
# Tracks_hPtNeg
# Tracks_hPtPos
# Tracks_hPtRatio

# %%
display(Image(filename=dir+'TracksQC_hPt.png'),
        Image(filename=dir+'TracksQC_hPtNeg.png'),
        Image(filename=dir+'TracksQC_hPtPos.png'),
        Image(filename=dir+'TracksQC_hPtRatio.png'))

# %% [markdown]
# ### Cosmics can be seen but didn't lead to error

# %%
Image(filename=dir+'TracksQC_h2DEtaPhi.png')
