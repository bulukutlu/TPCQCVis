# %%
# %%capture
import ROOT
import glob
import math
import sys
import numpy as np
import pandas as pd
from IPython.display import display, Markdown, HTML
import ipywidgets as widgets
from TPCQCVis.src.drawHistograms import *
from TPCQCVis.src.drawTrending import *
from TPCQCVis.src.drawMultiTrending import *
from TPCQCVis.src.checkHistograms import *
from TPCQCVis.src.checkTrending import *
from TPCQCVis.src.utility import *
import warnings
from copy import copy
warnings.filterwarnings('ignore')

# %%
# %jsroot on
display(HTML("<style>.container { width:95% !important; align-items: center;}</style>"))
display(HTML("<style>table {float:left;}</style>"))
ROOT.gErrorIgnoreLevel = ROOT.kError
#display(HTML('<style>{}</style>'.format(CSS)))
#ROOT.gStyle.SetPalette(57)
# Out:
# <style>.container { width:95% !important; align-items: center;}</style>
# <style>table {float:left;}</style>

# %%
def findHist(name, hists):
    for hist in hists:
        if hist.GetName() == name:
            return hist
            break
    return None

# %% [markdown]
# # Report for comparing new and old versions of apass1
# + Periods investigated LHC23l, LHC23s, LHC23v, LHC23za
# + Picking one random run from each period

# %%
periodName = "LHC23l"
passName = "apass1"
runNumber = 536108
runList = [runNumber]
# Read files downloaded from QCDB
fileList = glob.glob("/home/berki/Downloads/comparison/"+periodName+"/"+str(runNumber)+"/*")
myFiles = [ROOT.TFile.Open(file,"READ") for file in fileList]
myHists = [file.Get("ccdb_object") for file in myFiles]
myNames = [hist.GetName() for hist in myHists]
# Read standard QC.root files
path = "/cave/alice-tpc-qc/data/2023/"
rootDataFile = [ROOT.TFile.Open(path+"/"+periodName+"/"+passName+"/"+str(runNumber)+"_QC.root","READ")]   
#print(myNames)

display(Markdown('--- '))
display(Markdown('## '+periodName+" - "+str(runNumber)))
# Out:
# ---
# ## LHC23l - 536108

# %%
# %jsroot on
objectName = "hNClustersAfterCuts"
display(Markdown('### '+objectName))
myObject = findHist(objectName, myHists)
if checkIfExists(rootDataFile,objectName):
    [hist,legend,canvas,pad1] = drawHistograms(objectName,rootDataFile,xAxisRange = [50,160])
    
    hist[0].SetTitle(str(runNumber)+" - "+hist[0].GetTitle())
    pad1.cd()
    ROOT.gPad.SetGrid(1)
    leg = ROOT.TLegend()
    myObject.SetLineWidth(3)
    myObject.SetLineColor(ROOT.kRed)
    myObject.Draw("SAME L")
    leg.AddEntry(hist[0],passName)
    leg.AddEntry(myObject,passName+"_old")
    leg.Draw()
    canvas.Draw()
# Out:
# ### hNClustersAfterCuts
# <div id="root_plot_1699986066091"
#      style="width: 796px; height: 572px">
# </div>
# <script>
#
# function display_root_plot_1699986066091(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":796,"fYtoAbsPixelk":572.00005,"fYtoPixelk":572.00005,"fYtoPixel":-572,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":0.00125628140703518,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00174825174825175,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPad","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":35.6249989662319,"fY1":-182509971.998052,"fX2":174.375001033768,"fY2":1642589639.19805,"fXtoAbsPixelk":-204.378319402241,"fXtoPixelk":-204.378319402241,"fXtoPixel":5.73693685144991,"fYtoAbsPixelk":514.800046590614,"fYtoPixelk":514.800046590614,"fYtoPixel":-3.13407551287095e-7,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":35.6249989662319,"fPixeltoXk":35.6249989662319,"fPixeltoX":0.174309047823538,"fAbsPixeltoYk":1642589639.19805,"fPixeltoYk":-182509971.998052,"fPixeltoY":-3190733.58600718,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":49.5,"fUymin":0,"fUxmax":160.5,"fUymax":1460079667.2,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":true,"fGridy":true,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":49.5,"fY1":0,"fX2":160.5,"fY2":1460079667.2,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":8,"fName":"hNClustersAfterCuts","fTitle":"536108 - Number of clusters","fLineColor":1,"fLineStyle":1,"fLineWidth":3,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":402,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":2048,"fName":"xaxis","fTitle":"# TPC clusters","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":400,"fXmin":-0.5,"fXmax":399.5,"fXbins":[],"fFirst":51,"fLast":161,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTi ...

# %%
# %jsroot on
objectName = "hPt"
display(Markdown('### '+objectName))
myObject = findHist(objectName, myHists)
if checkIfExists(rootDataFile,objectName):
    [hist,legend,canvas,pad1] = drawHistograms(objectName,rootDataFile,log="logxy")
    
    hist[0].SetTitle(str(runNumber)+" - "+hist[0].GetTitle())
    pad1.cd()
    ROOT.gPad.SetGrid(1)
    leg = ROOT.TLegend()
    myObject.SetLineWidth(3)
    myObject.SetLineColor(ROOT.kRed)
    myObject.Draw("SAME L")
    leg.AddEntry(hist[0],passName)
    leg.AddEntry(myObject,passName+"_old")
    leg.Draw()
    canvas.Draw()
# Out:
# ### hPt
# <div id="root_plot_1699986066222"
#      style="width: 796px; height: 572px">
# </div>
# <script>
#
# function display_root_plot_1699986066222(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":796,"fYtoAbsPixelk":572.00005,"fYtoPixelk":572.00005,"fYtoPixel":-572,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":0.00125628140703518,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00174825174825175,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPad","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-1.62628751881355,"fY1":4.64498572698401,"fX2":1.62628751881355,"fY2":9.8860211432698,"fXtoAbsPixelk":398.00005,"fXtoPixelk":398.00005,"fXtoPixel":244.729173283184,"fYtoAbsPixelk":1078.94793811745,"fYtoPixelk":1078.94793811745,"fYtoPixel":-109.13873968922,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":-1.62628751881355,"fPixeltoXk":-1.62628751881355,"fPixeltoX":0.00408614954475766,"fAbsPixeltoYk":9.8860211432698,"fPixeltoYk":4.64498572698401,"fPixeltoY":-0.00916264932917097,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":-1.30102999566398,"fUymin":5.16908929985159,"fUxmax":1.30102999566398,"fUymax":9.36191757040222,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":1,"fLogy":1,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":true,"fGridy":true,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":-1.30102999566398,"fY1":5.16908929985159,"fX2":1.30102999566398,"fY2":9.36191757040222,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":8,"fName":"hPt","fTitle":"536108 - Transverse momentum","fLineColor":1,"fLineStyle":1,"fLineWidth":3,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":102,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"xaxis","fTitle":"p_T","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":100,"fXmin":0.05,"fXmax":20,"fXbins":{"$arr":"Float64","len":101,"v":[0.05,0.0530872958927489,0.0563652197040855,0.0598455419298118,0.0635407598457967,0.0674641423836782,0.0716297777774573,0.0760526241520746,0.0807485632356242,0.0857344573880786,0.091028210151304,0.0966488305377922,0.1026165012889 ...

# %%
# %jsroot on

objectName = "hPhiAside"
display(Markdown('### '+objectName))
myObject = findHist(objectName, myHists)
if checkIfExists(rootDataFile,objectName):
    [hist,legend,canvas,pad1] = drawHistograms(objectName,rootDataFile)
    
    hist[0].SetTitle(str(runNumber)+" - "+hist[0].GetTitle())
    pad1.cd()
    leg = ROOT.TLegend()
    myObject.SetLineWidth(3)
    myObject.SetLineColor(ROOT.kRed)
    myObject.Draw("SAME L")
    sectorBoundary = ROOT.TLine(0,hist[0].GetMinimum(),0,hist[0].GetMaximum())
    sectorBoundary.SetLineStyle(2)
    sectorNum = ROOT.TText(.5,.5,"test")
    sectorNum.SetTextAlign(22)
    sectorNum.SetTextColor(ROOT.kGray+1)
    sectorNum.SetTextFont(0)
    for j in range(19):
        sectorBoundary.DrawLine((j*2*math.pi)/18,hist[0].GetMinimum(),(j*2*math.pi)/18,hist[0].GetMaximum())
        if j < 18 : sectorNum.DrawText(((j+0.5)*2*math.pi)/18,hist[0].GetMaximum()*0.95+hist[0].GetMinimum()*0.05,str(j))
    leg.AddEntry(hist[0],passName)
    leg.AddEntry(myObject,passName+"_old")
    leg.Draw()
    canvas.Draw()
# Out:
# ### hPhiAside
# <div id="root_plot_1699986066378"
#      style="width: 796px; height: 572px">
# </div>
# <script>
#
# function display_root_plot_1699986066378(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":796,"fYtoAbsPixelk":572.00005,"fYtoPixelk":572.00005,"fYtoPixel":-572,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":0.00125628140703518,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00174825174825175,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPad","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.785398221914175,"fY1":59559781.357224,"fX2":7.06858352909376,"fY2":67985439.282776,"fXtoAbsPixelk":79.6000547445299,"fXtoPixelk":79.6000547445299,"fXtoPixel":101.349866250688,"fYtoAbsPixelk":4615.38695667884,"fYtoPixelk":4615.38695667884,"fYtoPixel":-6.78878735707182e-5,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":-0.785398221914175,"fPixeltoXk":-0.785398221914175,"fPixeltoX":0.00986681124498484,"fAbsPixeltoYk":67985439.282776,"fPixeltoYk":59559781.357224,"fPixeltoY":-14730.1711985176,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":60402347.2,"fUxmax":6.28318530717959,"fUymax":67142873.44,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":60402347.2,"fX2":6.28318530717959,"fY2":67142873.44,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":8,"fName":"hPhiAside","fTitle":"536108 - Azimuthal angle, A side","fLineColor":1,"fLineStyle":1,"fLineWidth":3,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":362,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"xaxis","fTitle":"phi","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":360,"fXmin":0,"fXmax":6.28318530717959,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fL ...

# %%
# %jsroot on

objectName = "hPhiCside"
display(Markdown('### '+objectName))
myObject = findHist(objectName, myHists)
if checkIfExists(rootDataFile,objectName):
    [hist,legend,canvas,pad1] = drawHistograms(objectName,rootDataFile)
    
    hist[0].SetTitle(str(runNumber)+" - "+hist[0].GetTitle())
    pad1.cd()
    leg = ROOT.TLegend()
    myObject.SetLineWidth(3)
    myObject.SetLineColor(ROOT.kRed)
    myObject.Draw("SAME L")
    sectorBoundary = ROOT.TLine(0,hist[0].GetMinimum(),0,hist[0].GetMaximum())
    sectorBoundary.SetLineStyle(2)
    sectorNum = ROOT.TText(.5,.5,"test")
    sectorNum.SetTextAlign(22)
    sectorNum.SetTextColor(ROOT.kGray+1)
    sectorNum.SetTextFont(0)
    for j in range(19):
        sectorBoundary.DrawLine((j*2*math.pi)/18,hist[0].GetMinimum(),(j*2*math.pi)/18,hist[0].GetMaximum())
        if j < 18 : sectorNum.DrawText(((j+0.5)*2*math.pi)/18,hist[0].GetMaximum()*0.95+hist[0].GetMinimum()*0.05,str(j))
    leg.AddEntry(hist[0],passName)
    leg.AddEntry(myObject,passName+"_old")
    leg.Draw()
    canvas.Draw()
# Out:
# ### hPhiCside
# <div id="root_plot_1699986066502"
#      style="width: 796px; height: 572px">
# </div>
# <script>
#
# function display_root_plot_1699986066502(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":796,"fYtoAbsPixelk":572.00005,"fYtoPixelk":572.00005,"fYtoPixel":-572,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":0.00125628140703518,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00174825174825175,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPad","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.785398221914175,"fY1":49335631.3552947,"fX2":7.06858352909376,"fY2":55335877.4447053,"fXtoAbsPixelk":79.6000547445299,"fXtoPixelk":79.6000547445299,"fXtoPixel":101.349866250688,"fYtoAbsPixelk":5275.13734049077,"fYtoPixelk":5275.13734049077,"fYtoPixel":-9.53294234063963e-5,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":-0.785398221914175,"fPixeltoXk":-0.785398221914175,"fPixeltoX":0.00986681124498484,"fAbsPixeltoYk":55335877.4447053,"fPixeltoYk":49335631.3552947,"fPixeltoY":-10489.9407157529,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":49935656,"fUxmax":6.28318530717959,"fUymax":54735852.8,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":49935656,"fX2":6.28318530717959,"fY2":54735852.8,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":8,"fName":"hPhiCside","fTitle":"536108 - Azimuthal angle, C side","fLineColor":1,"fLineStyle":1,"fLineWidth":3,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":362,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"xaxis","fTitle":"phi","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":360,"fXmin":0,"fXmax":6.28318530717959,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLab ...

# %%
# %jsroot on
objectName = "hEta"
display(Markdown('### '+objectName))
myObject = findHist(objectName, myHists)
if checkIfExists(rootDataFile,objectName):
    [hist,legend,canvas,pad1] = drawHistograms(objectName,rootDataFile,xAxisRange = [-1.1,1.1])
    
    hist[0].SetTitle(str(runNumber)+" - "+hist[0].GetTitle())
    pad1.cd()
    ROOT.gPad.SetGrid(1)
    leg = ROOT.TLegend()
    myObject.SetLineWidth(3)
    myObject.SetLineColor(ROOT.kRed)
    myObject.Draw("SAME L")
    leg.AddEntry(hist[0],passName)
    leg.AddEntry(myObject,passName+"_old")
    leg.Draw()
    canvas.Draw()
# Out:
# ### hEta
# <div id="root_plot_1699986066620"
#      style="width: 796px; height: 572px">
# </div>
# <script>
#
# function display_root_plot_1699986066620(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":796,"fYtoAbsPixelk":572.00005,"fYtoPixelk":572.00005,"fYtoPixel":-572,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":0.00125628140703518,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00174825174825175,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPad","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-1.3750000204891,"fY1":-39429842.3377521,"fX2":1.3750000204891,"fY2":354868557.537752,"fXtoAbsPixelk":398.00005,"fXtoPixelk":398.00005,"fXtoPixel":289.454541141336,"fYtoAbsPixelk":514.800046590614,"fYtoPixelk":514.800046590614,"fYtoPixel":-1.45067796415254e-6,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":-1.3750000204891,"fPixeltoXk":-1.3750000204891,"fPixeltoX":0.00345477392082688,"fAbsPixeltoYk":354868557.537752,"fPixeltoYk":-39429842.3377521,"fPixeltoY":-689332.866915217,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":-1.1,"fUymin":0,"fUxmax":1.1,"fUymax":315438715.2,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":true,"fGridy":true,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":-1.1,"fY1":0,"fX2":1.1,"fY2":315438715.2,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":8,"fName":"hEta","fTitle":"536108 - Pseudorapidity","fLineColor":1,"fLineStyle":1,"fLineWidth":3,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":402,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":2048,"fName":"xaxis","fTitle":"eta","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":400,"fXmin":-2,"fXmax":2,"fXbins":[],"fFirst":91,"fLast":310,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitl ...

# %%
periodName = "LHC23s"
passName = "apass1"
runNumber = 536906
runList = [runNumber]
# Read files downloaded from QCDB
fileList = glob.glob("/home/berki/Downloads/comparison/"+periodName+"/"+str(runNumber)+"/*")
myFiles = [ROOT.TFile.Open(file,"READ") for file in fileList]
myHists = [file.Get("ccdb_object") for file in myFiles]
myNames = [hist.GetName() for hist in myHists]
# Read standard QC.root files
path = "/cave/alice-tpc-qc/data/2023/"
rootDataFile = [ROOT.TFile.Open(path+"/"+periodName+"/"+passName+"/"+str(runNumber)+"_QC.root","READ")]   
#print(myNames)

display(Markdown('--- '))
display(Markdown('## '+periodName+" - "+str(runNumber)))
# Out:
# ---
# ## LHC23s - 536906

# %%
# %jsroot on
objectName = "hNClustersAfterCuts"
display(Markdown('### '+objectName))
myObject = findHist(objectName, myHists)
if checkIfExists(rootDataFile,objectName):
    [hist,legend,canvas,pad1] = drawHistograms(objectName,rootDataFile,xAxisRange =

#      style="width: 796px; height: 572px">
# </div>
# <script>
#
# function display_root_plot_1699986067326(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":796,"fYtoAbsPixelk":572.00005,"fYtoPixelk":572.00005,"fYtoPixel":-572,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":0.00125628140703518,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00174825174825175,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPad","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-1.3750000204891,"fY1":-34054245.1372389,"fX2":1.3750000204891,"fY2":306488185.937239,"fXtoAbsPixelk":398.00005,"fXtoPixelk":398.00005,"fXtoPixel":289.454541141336,"fYtoAbsPixelk":514.800046590614,"fYtoPixelk":514.800046590614,"fYtoPixel":-1.67967321486262e-6,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":-1.3750000204891,"fPixeltoXk":-1.3750000204891,"fPixeltoX":0.00345477392082688,"fAbsPixeltoYk":306488185.937239,"fPixeltoYk":-34054245.1372389,"fPixeltoY":-595353.900479857,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":-1.1,"fUymin":0,"fUxmax":1.1,"fUymax":272433940.8,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":true,"fGridy":true,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":-1.1,"fY1":0,"fX2":1.1,"fY2":272433940.8,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":8,"fName":"hEta","fTitle":"536906 - Pseudorapidity","fLineColor":1,"fLineStyle":1,"fLineWidth":3,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":402,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":2048,"fName":"xaxis","fTitle":"eta","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":400,"fXmin":-2,"fXmax":2,"fXbins":[],"fFirst":91,"fLast":310,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitl ...

# %%
periodName = "LHC23v"
passName = "apass1"
runNumber = 537505
runList = [runNumber]
# Read files downloaded from QCDB
fileList = glob.glob("/home/berki/Downloads/comparison/"+periodName+"/"+str(runNumber)+"/*")
myFiles = [ROOT.TFile.Open(file,"READ") for file in fileList]
myHists = [file.Get("ccdb_object") for file in myFiles]
myNames = [hist.GetName() for hist in myHists]
# Read standard QC.root files
path = "/cave/alice-tpc-qc/data/2023/"
rootDataFile = [ROOT.TFile.Open(path+"/"+periodName+"/"+passName+"/"+str(runNumber)+"_QC.root","READ")]   
#print(myNames)

display(Markdown('--- '))
display(Markdown('## '+periodName+" - "+str(runNumber)))
# Out:
# ---
# ## LHC23v - 537505

# %%
# %jsroot on
objectName = "hNClustersAfterCuts"
display(Markdown('### '+objectName))
myObject = findHist(objectName, myHists)
if checkIfExists(rootDataFile,objectName):
    [hist,legend,canvas,pad1] = drawHistograms(objectName,rootDataFile,xAxisRange = [50,160])
    
    hist[0].SetTitle(str(runNumber)+" - "+hist[0].GetTitle())
    pad1.cd()
    ROOT.gPad.SetGrid(1)
    leg = ROOT.TLegend()
    myObject.SetLineWidth(3)
    myObject.SetLineColor(ROOT.kRed)
    myObject.Draw("SAME L")
    leg.AddEntry(hist[0],passName)
    leg.AddEntry(myObject,passName+"_old")
    leg.Draw()
    canvas.Draw()
# Out:
# ### hNClustersAfterCuts
# <div id="root_plot_1699986067553"
#      style="width: 796px; height: 572px">
# </div>
# <script>
#
# function display_root_plot_1699986067553(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":796,"fYtoAbsPixelk":572.00005,"fYtoPixelk":572.00005,"fYtoPixel":-572,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":0.00125628140703518,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00174825174825175,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPad","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":35.6249989662319,"fY1":-167306155.66528,"fX2":174.375001033768,"fY2":1505755301.26528,"fXtoAbsPixelk":-204.378319402241,"fXtoPixelk":-204.378319402241,"fXtoPixel":5.73693685144991,"fYtoAbsPixelk":514.800046590614,"fYtoPixelk":514.800046590614,"fYtoPixel":-3.41888217931579e-7,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":35.6249989662319,"fPixeltoXk":35.6249989662319,"fPixeltoX":0.174309047823538,"fAbsPixeltoYk":1505755301.26528,"fPixeltoYk":-167306155.66528,"fPixeltoY":-2924932.61701147,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":49.5,"fUymin":0,"fUxmax":160.5,"fUymax":1338449145.6,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":true,"fGridy":true,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":49.5,"fY1":0,"fX2":160.5,"fY2":1338449145.6,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":8,"fName":"hNClustersAfterCuts","fTitle":"537505 - Number of clusters","fLineColor":1,"fLineStyle":1,"fLineWidth":3,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":402,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":2048,"fName":"xaxis","fTitle":"# TPC clusters","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":400,"fXmin":-0.5,"fXmax":399.5,"fXbins":[],"fFirst":51,"fLast":161,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTick ...

# %%
# %jsroot on
objectName = "hPt"
display(Markdown('### '+objectName))
myObject = findHist(objectName, myHists)
if checkIfExists(rootDataFile,objectName):
    [hist,legend,canvas,pad1] = drawHistograms(objectName,rootDataFile,log="logxy")
    
    hist[0].SetTitle(str(runNumber)+" - "+hist[0].GetTitle())
    pad1.cd()
    ROOT.gPad.SetGrid(1)
    leg = ROOT.TLegend()
    myObject.SetLineWidth(3)
    myObject.SetLineColor(ROOT.kRed)
    myObject.Draw("SAME L")
    leg.AddEntry(hist[0],passName)
    leg.AddEntry(myObject,passName+"_old")
    leg.Draw()
    canvas.Draw()
# Out:
# ### hPt
# <div id="root_plot_1699986067668"
#      style="width: 796px; height: 572px">
# </div>
# <script>
#
# function display_root_plot_1699986067668(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":796,"fYtoAbsPixelk":572.00005,"fYtoPixelk":572.00005,"fYtoPixel":-572,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":0.00125628140703518,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00174825174825175,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPad","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-1.62628751881355,"fY1":4.65080526903321,"fX2":1.62628751881355,"fY2":9.82528093219996,"fXtoAbsPixelk":398.00005,"fXtoPixelk":398.00005,"fXtoPixel":244.729173283184,"fYtoAbsPixelk":1086.11216242589,"fYtoPixelk":1086.11216242589,"fYtoPixel":-110.542601267147,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":-1.62628751881355,"fPixeltoXk":-1.62628751881355,"fPixeltoX":0.00408614954475766,"fAbsPixeltoYk":9.82528093219996,"fPixeltoYk":4.65080526903321,"fPixeltoY":-0.00904628612441741,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":-1.30102999566398,"fUymin":5.16825286619216,"fUxmax":1.30102999566398,"fUymax":9.30783333504101,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":1,"fLogy":1,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":true,"fGridy":true,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":-1.30102999566398,"fY1":5.16825286619216,"fX2":1.30102999566398,"fY2":9.30783333504101,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":8,"fName":"hPt","fTitle":"537505 - Transverse momentum","fLineColor":1,"fLineStyle":1,"fLineWidth":3,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":102,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"xaxis","fTitle":"p_T","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":100,"fXmin":0.05,"fXmax":20,"fXbins":{"$arr":"Float64","len":101,"v":[0.05,0.0530872958927489,0.0563652197040855,0.0598455419298118,0.0635407598457967,0.0674641423836782,0.0716297777774573,0.0760526241520746,0.0807485632356242,0.0857344573880786,0.091028210151304,0.0966488305377922,0.1026165012 ...

# %%
# %jsroot on

objectName = "hPhiAside"
display(Markdown('### '+objectName))
myObject = findHist(objectName, myHists)
if checkIfExists(rootDataFile,objectName):
    [hist,legend,canvas,pad1] = drawHistograms(objectName,rootDataFile)
    
    hist[0].SetTitle(str(runNumber)+" - "+hist[0].GetTitle())
    pad1.cd()
    leg = ROOT.TLegend()
    myObject.SetLineWidth(3)
    myObject.SetLineColor(ROOT.kRed)
    myObject.Draw("SAME L")
    sectorBoundary = ROOT.TLine(0,hist[0].GetMinimum(),0,hist[0].GetMaximum())
    sectorBoundary.SetLineStyle(2)
    sectorNum = ROOT.TText(.5,.5,"test")
    sectorNum.SetTextAlign(22)
    sectorNum.SetTextColor(ROOT.kGray+1)
    sectorNum.SetTextFont(0)
    for j in range(19):
        sectorBoundary.DrawLine((j*2*math.pi)/18,hist[0].GetMinimum(),(j*2*math.pi)/18,hist[0].GetMaximum())
        if j < 18 : sectorNum.DrawText(((j+0.5)*2*math.pi)/18,hist[0].GetMaximum()*0.95+hist[0].GetMinimum()*0.05,str(j))
    leg.AddEntry(hist[0],passName)
    leg.AddEntry(myObject,passName+"_old")
    leg.Draw()
    canvas.Draw()
# Out:
# ### hPhiAside
# <div id="root_plot_1699986067789"
#      style="width: 796px; height: 572px">
# </div>
# <script>
#
# function display_root_plot_1699986067789(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":796,"fYtoAbsPixelk":572.00005,"fYtoPixelk":572.00005,"fYtoPixel":-572,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":0.00125628140703518,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00174825174825175,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPad","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.785398221914175,"fY1":52581388.7500528,"fX2":7.06858352909376,"fY2":60459594.7799472,"fXtoAbsPixelk":79.6000547445299,"fXtoPixelk":79.6000547445299,"fXtoPixel":101.349866250688,"fYtoAbsPixelk":4389.69080991444,"fYtoPixelk":4389.69080991444,"fYtoPixel":-7.26053619097424e-5,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":-0.785398221914175,"fPixeltoXk":-0.785398221914175,"fPixeltoX":0.00986681124498484,"fAbsPixeltoYk":60459594.7799472,"fPixeltoYk":52581388.7500528,"fPixeltoY":-13773.0874648504,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":53369209.4,"fUxmax":6.28318530717959,"fUymax":59671774.13,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":53369209.4,"fX2":6.28318530717959,"fY2":59671774.13,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":8,"fName":"hPhiAside","fTitle":"537505 - Azimuthal angle, A side","fLineColor":1,"fLineStyle":1,"fLineWidth":3,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":362,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"xaxis","fTitle":"phi","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":360,"fXmin":0,"fXmax":6.28318530717959,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005 ...

# %%
# %jsroot on

objectName = "hPhiCside"
display(Markdown('### '+objectName))
myObject = findHist(objectName, myHists)
if checkIfExists(rootDataFile,objectName):
    [hist,legend,canvas,pad1] = drawHistograms(objectName,rootDataFile)
    
    hist[0].SetTitle(str(runNumber)+" - "+hist[0].GetTitle())
    pad1.cd()
    leg = ROOT.TLegend()
    myObject.SetLineWidth(3)
    myObject.SetLineColor(ROOT.kRed)
    myObject.Draw("SAME L")
    sectorBoundary = ROOT.TLine(0,hist[0].GetMinimum(),0,hist[0].GetMaximum())
    sectorBoundary.SetLineStyle(2)
    sectorNum = ROOT.TText(.5,.5,"test")
    sectorNum.SetTextAlign(22)
    sectorNum.SetTextColor(ROOT.kGray+1)
    sectorNum.SetTextFont(0)
    for j in range(19):
        sectorBoundary.DrawLine((j*2*math.pi)/18,hist[0].GetMinimum(),(j*2*math.pi)/18,hist[0].GetMaximum())
        if j < 18 : sectorNum.DrawText(((j+0.5)*2*math.pi)/18,hist[0].GetMaximum()*0.95+hist[0].GetMinimum()*0.05,str(j))
    leg.AddEntry(hist[0],passName)
    leg.AddEntry(myObject,passName+"_old")
    leg.Draw()
    canvas.Draw()
# Out:
# ### hPhiCside
# <div id="root_plot_1699986067910"
#      style="width: 796px; height: 572px">
# </div>
# <script>
#
# function display_root_plot_1699986067910(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":796,"fYtoAbsPixelk":572.00005,"fYtoPixelk":572.00005,"fYtoPixel":-572,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":0.00125628140703518,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00174825174825175,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPad","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.785398221914175,"fY1":43622957.15431,"fX2":7.06858352909376,"fY2":48748733.30569,"fXtoAbsPixelk":79.6000547445299,"fXtoPixelk":79.6000547445299,"fXtoPixel":101.349866250688,"fYtoAbsPixelk":5440.01042644755,"fYtoPixelk":5440.01042644755,"fYtoPixel":-1.11592856009914e-4,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":-0.785398221914175,"fPixeltoXk":-0.785398221914175,"fPixeltoX":0.00986681124498484,"fAbsPixeltoYk":48748733.30569,"fPixeltoYk":43622957.15431,"fPixeltoY":-8961.14711779723,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":44135534.8,"fUxmax":6.28318530717959,"fUymax":48236155.66,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":44135534.8,"fX2":6.28318530717959,"fY2":48236155.66,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":8,"fName":"hPhiCside","fTitle":"537505 - Azimuthal angle, C side","fLineColor":1,"fLineStyle":1,"fLineWidth":3,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":362,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"xaxis","fTitle":"phi","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":360,"fXmin":0,"fXmax":6.28318530717959,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabel ...

# %%
# %jsroot on
objectName = "hEta"
display(Markdown('### '+objectName))
myObject = findHist(objectName, myHists)
if checkIfExists(rootDataFile,objectName):
    [hist,legend,canvas,pad1] = drawHistograms(objectName,rootDataFile,xAxisRange = [-1.1,1.1])
    
    hist[0].SetTitle(str(runNumber)+" - "+hist[0].GetTitle())
    pad1.cd()
    ROOT.gPad.SetGrid(1)
    leg = ROOT.TLegend()
    myObject.SetLineWidth(3)
    myObject.SetLineColor(ROOT.kRed)
    myObject.Draw("SAME L")
    leg.AddEntry(hist[0],passName)
    leg.AddEntry(myObject,passName+"_old")
    leg.Draw()
    canvas.Draw()
# Out:
# ### hEta
# <div id="root_plot_1699986068026"
#      style="width: 796px; height: 572px">
# </div>
# <script>
#
# function display_root_plot_1699986068026(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":796,"fYtoAbsPixelk":572.00005,"fYtoPixelk":572.00005,"fYtoPixel":-572,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":0.00125628140703518,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00174825174825175,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPad","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-1.3750000204891,"fY1":-34809949.0935433,"fX2":1.3750000204891,"fY2":313289521.093543,"fXtoAbsPixelk":398.00005,"fXtoPixelk":398.00005,"fXtoPixel":289.454541141336,"fYtoAbsPixelk":514.800046590614,"fYtoPixelk":514.800046590614,"fYtoPixel":-1.64320847628001e-6,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":-1.3750000204891,"fPixeltoXk":-1.3750000204891,"fPixeltoX":0.00345477392082688,"fAbsPixeltoYk":313289521.093543,"fPixeltoYk":-34809949.0935433,"fPixeltoY":-608565.507320081,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":-1.1,"fUymin":0,"fUxmax":1.1,"fUymax":278479572,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":true,"fGridy":true,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":-1.1,"fY1":0,"fX2":1.1,"fY2":278479572,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":8,"fName":"hEta","fTitle":"537505 - Pseudorapidity","fLineColor":1,"fLineStyle":1,"fLineWidth":3,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":402,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":2048,"fName":"xaxis","fTitle":"eta","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":400,"fXmin":-2,"fXmax":2,"fXbins":[],"fFirst":91,"fLast":310,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleCol ...

# %%
periodName = "LHC23s"
passName = "apass1"
runNumber = 536906
runList = [runNumber]
# Read files downloaded from QCDB
fileList = glob.glob("/home/berki/Downloads/comparison/"+periodName+"/"+str(runNumber)+"/*")
myFiles = [ROOT.TFile.Open(file,"READ") for file in fileList]
myHists = [file.Get("ccdb_object") for file in myFiles]
myNames = [hist.GetName() for hist in myHists]
# Read standard QC.root files
path = "/cave/alice-tpc-qc/data/2023/"
rootDataFile = [ROOT.TFile.Open(path+"/"+periodName+"/"+passName+"/"+str(runNumber)+"_QC.root","READ")]   
#print(myNames)

display(Markdown('--- '))
display(Markdown('## '+periodName+" - "+str(runNumber)))
# Out:
# ---
# ## LHC23s - 536906

# %%
# %jsroot on
objectName = "hNClustersAfterCuts"
display(Markdown('### '+objectName))
myObject = findHist(objectName, myHists)
if checkIfExists(rootDataFile,objectName):
    [hist,legend,canvas,pad1] = drawHistograms(objectName,rootDataFile,xAxisRange = [50,160])
    
    hist[0].SetTitle(str(runNumber)+" - "+hist[0].GetTitle())
    pad1.cd()
    ROOT.gPad.SetGrid(1)
    leg = ROOT.TLegend()
    myObject.SetLineWidth(3)
    myObject.SetLineColor(ROOT.kRed)
    myObject.Draw("SAME L")
    leg.AddEntry(hist[0],passName)
    leg.AddEntry(myObject,passName+"_old")
    leg.Draw()
    canvas.Draw()
# Out:
# ### hNClustersAfterCuts
# <div id="root_plot_1699986068254"
#      style="width: 796px; height: 572px">
# </div>
# <script>
#
# function display_root_plot_1699986068254(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":796,"fYtoAbsPixelk":572.00005,"fYtoPixelk":572.00005,"fYtoPixel":-572,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":0.00125628140703518,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00174825174825175,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPad","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":35.6249989662319,"fY1":-160368628.748394,"fX2":174.375001033768,"fY2":1443317563.14839,"fXtoAbsPixelk":-204.378319402241,"fXtoPixelk":-204.378319402241,"fXtoPixel":5.73693685144991,"fYtoAbsPixelk":514.800046590614,"fYtoPixelk":514.800046590614,"fYtoPixel":-3.56678259680878e-7,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk
8,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":true,"fGridy":true,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":-1.1,"fY1":0,"fX2":1.1,"fY2":272433940.8,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":8,"fName":"hEta","fTitle":"536906 - Pseudorapidity","fLineColor":1,"fLineStyle":1,"fLineWidth":3,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":402,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":2048,"fName":"xaxis","fTitle":"eta","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":400,"fXmin":-2,"fXmax":2,"fXbins":[],"fFirst":91,"fLast":310,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitl ...

# %%
periodName = "LHC23za"
passName = "apass1"
runNumber = 537769
runList = [runNumber]
# Read files downloaded from QCDB
fileList = glob.glob("/home/berki/Downloads/comparison/"+periodName+"/"+str(runNumber)+"/*")
myFiles = [ROOT.TFile.Open(file,"READ") for file in fileList]
myHists = [file.Get("ccdb_object") for file in myFiles]
myNames = [hist.GetName() for hist in myHists]
# Read standard QC.root files
path = "/cave/alice-tpc-qc/data/2023/"
rootDataFile = [ROOT.TFile.Open(path+"/"+periodName+"/"+passName+"/"+str(runNumber)+"_QC.root","READ")]   
#print(myNames)

display(Markdown('--- '))
display(Markdown('## '+periodName+" - "+str(runNumber)))
# Out:
# ---
# ## LHC23za - 537769

# %%
# %jsroot on
objectName = "hNClustersAfterCuts"
display(Markdown('### '+objectName))
myObject = findHist(objectName, myHists)
if checkIfExists(rootDataFile,objectName):
    [hist,legend,canvas,pad1] = drawHistograms(objectName,rootDataFile,xAxisRange = [50,160])
    
    hist[0].SetTitle(str(runNumber)+" - "+hist[0].GetTitle())
    pad1.cd()
    ROOT.gPad.SetGrid(1)
    leg = ROOT.TLegend()
    myObject.SetLineWidth(3)
    myObject.SetLineColor(ROOT.kRed)
    myObject.Draw("SAME L")
    leg.AddEntry(hist[0],passName)
    leg.AddEntry(myObject,passName+"_old")
    leg.Draw()
    canvas.Draw()
# Out:
# ### hNClustersAfterCuts
# <div id="root_plot_1699986068964"
#      style="width: 796px; height: 572px">
# </div>
# <script>
#
# function display_root_plot_1699986068964(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":796,"fYtoAbsPixelk":572.00005,"fYtoPixelk":572.00005,"fYtoPixel":-572,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":0.00125628140703518,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00174825174825175,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPad","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":35.6249989662319,"fY1":-72866914.2290081,"fX2":174.375001033768,"fY2":655802184.629008,"fXtoAbsPixelk":-204.378319402241,"fXtoPixelk":-204.378319402241,"fXtoPixel":5.73693685144991,"fYtoAbsPixelk":514.800046590614,"fYtoPixelk":514.800046590614,"fYtoPixel":-7.84992805234158e-7,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":35.6249989662319,"fPixeltoXk":35.6249989662319,"fPixeltoX":0.174309047823538,"fAbsPixeltoYk":655802184.629008,"fPixeltoYk":-72866914.2290081,"fPixeltoY":-1273897.02597555,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":49.5,"fUymin":0,"fUxmax":160.5,"fUymax":582935270.4,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":true,"fGridy":true,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":49.5,"fY1":0,"fX2":160.5,"fY2":582935270.4,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":8,"fName":"hNClustersAfterCuts","fTitle":"537769 - Number of clusters","fLineColor":1,"fLineStyle":1,"fLineWidth":3,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":402,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":2048,"fName":"xaxis","fTitle":"# TPC clusters","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":400,"fXmin":-0.5,"fXmax":399.5,"fXbins":[],"fFirst":51,"fLast":161,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTick ...

# %%
# %jsroot on
objectName = "hPt"
display(Markdown('### '+objectName))
myObject = findHist(objectName, myHists)
if checkIfExists(rootDataFile,objectName):
    [hist,legend,canvas,pad1] = drawHistograms(objectName,rootDataFile,log="logxy")
    
    hist[0].SetTitle(str(runNumber)+" - "+hist[0].GetTitle())
    pad1.cd()
    ROOT.gPad.SetGrid(1)
    leg = ROOT.TLegend()
    myObject.SetLineWidth(3)
    myObject.SetLineColor(ROOT.kRed)
    myObject.Draw("SAME L")
    leg.AddEntry(hist[0],passName)
    leg.AddEntry(myObject,passName+"_old")
    leg.Draw()
    canvas.Draw()
# Out:
# ### hPt
# <div id="root_plot_1699986069080"
#      style="width: 796px; height: 572px">
# </div>
# <script>
#
# function display_root_plot_1699986069080(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":796,"fYtoAbsPixelk":572.00005,"fYtoPixelk":572.00005,"fYtoPixel":-572,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":0.00125628140703518,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00174825174825175,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPad","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-1.62628751881355,"fY1":4.23868473259425,"fX2":1.62628751881355,"fY2":9.46777057471338,"fXtoAbsPixelk":398.00005,"fXtoPixelk":398.00005,"fXtoPixel":244.729173283184,"fYtoAbsPixelk":1035.66190988283,"fYtoPixelk":1035.66190988283,"fYtoPixel":-109.388144939727,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":-1.62628751881355,"fPixeltoXk":-1.62628751881355,"fPixeltoX":0.00408614954475766,"fAbsPixeltoYk":9.46777057471338,"fPixeltoYk":4.23868473259425,"fPixeltoY":-0.00914175846524323,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":-1.30102999566398,"fUymin":4.76159334797395,"fUxmax":1.30102999566398,"fUymax":8.94486195933369,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":1,"fLogy":1,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":true,"fGridy":true,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":-1.30102999566398,"fY1":4.76159334797395,"fX2":1.30102999566398,"fY2":8.94486195933369,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":8,"fName":"hPt","fTitle":"537769 - Transverse momentum","fLineColor":1,"fLineStyle":1,"fLineWidth":3,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":102,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"xaxis","fTitle":"p_T","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":100,"fXmin":0.05,"fXmax":20,"fXbins":{"$arr":"Float64","len":101,"v":[0.05,0.0530872958927489,0.0563652197040855,0.0598455419298118,0.0635407598457967,0.0674641423836782,0.0716297777774573,0.0760526241520746,0.0807485632356242,0.0857344573880786,0.091028210151304,0.0966488305377922,0.1026165012 ...

# %%
# %jsroot on

objectName = "hPhiAside"
display(Markdown('### '+objectName))
myObject = findHist(objectName, myHists)
if checkIfExists(rootDataFile,objectName):
    [hist,legend,canvas,pad1] = drawHistograms(objectName,rootDataFile)
    
    hist[0].SetTitle(str(runNumber)+" - "+hist[0].GetTitle())
    pad1.cd()
    leg = ROOT.TLegend()
    myObject.SetLineWidth(3)
    myObject.SetLineColor(ROOT.kRed)
    myObject.Draw("SAME L")
    sectorBoundary = ROOT.TLine(0,hist[0].GetMinimum(),0,hist[0].GetMaximum())
    sectorBoundary.SetLineStyle(2)
    sectorNum = ROOT.TText(.5,.5,"test")
    sectorNum.SetTextAlign(22)
    sectorNum.SetTextColor(ROOT.kGray+1)
    sectorNum.SetTextFont(0)
    for j in range(19):
        sectorBoundary.DrawLine((j*2*math.pi)/18,hist[0].GetMinimum(),(j*2*math.pi)/18,hist[0].GetMaximum())
        if j < 18 : sectorNum.DrawText(((j+0.5)*2*math.pi)/18,hist[0].GetMaximum()*0.95+hist[0].GetMinimum()*0.05,str(j))
    leg.AddEntry(hist[0],passName)
    leg.AddEntry(myObject,passName+"_old")
    leg.Draw()
    canvas.Draw()
# Out:
# ### hPhiAside
# <div id="root_plot_1699986069200"
#      style="width: 796px; height: 572px">
# </div>
# <script>
#
# function display_root_plot_1699986069200(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":796,"fYtoAbsPixelk":572.00005,"fYtoPixelk":572.00005,"fYtoPixel":-572,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":0.00125628140703518,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00174825174825175,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPad","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.785398221914175,"fY1":22893504.0581933,"fX2":7.06858352909376,"fY2":26239776.2768067,"fXtoAbsPixelk":79.6000547445299,"fXtoPixelk":79.6000547445299,"fXtoPixel":101.349866250688,"fYtoAbsPixelk":4485.33508844856,"fYtoPixelk":4485.33508844856,"fYtoPixel":-1.70936481741773e-4,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":-0.785398221914175,"fPixeltoXk":-0.785398221914175,"fPixeltoX":0.00986681124498484,"fAbsPixeltoYk":26239776.2768067,"fPixeltoYk":22893504.0581933,"fPixeltoY":-5850.12625631703,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":23228131.3,"fUxmax":6.28318530717959,"fUymax":25905149.035,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":23228131.3,"fX2":6.28318530717959,"fY2":25905149.035,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":8,"fName":"hPhiAside","fTitle":"537769 - Azimuthal angle, A side","fLineColor":1,"fLineStyle":1,"fLineWidth":3,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":362,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"xaxis","fTitle":"phi","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":360,"fXmin":0,"fXmax":6.28318530717959,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.0 ...

# %%
# %jsroot on

objectName = "hPhiCside"
display(Markdown('### '+objectName))
myObject = findHist(objectName, myHists)
if checkIfExists(rootDataFile,objectName):
    [hist,legend,canvas,pad1] = drawHistograms(objectName,rootDataFile)
    
    hist[0].SetTitle(str(runNumber)+" - "+hist[0].GetTitle())
    pad1.cd()
    leg = ROOT.TLegend()
    myObject.SetLineWidth(3)
    myObject.SetLineColor(ROOT.kRed)
    myObject.Draw("SAME L")
    sectorBoundary = ROOT.TLine(0,hist[0].GetMinimum(),0,hist[0].GetMaximum())
    sectorBoundary.SetLineStyle(2)
    sectorNum = ROOT.TText(.5,.5,"test")
    sectorNum.SetTextAlign(22)
    sectorNum.SetTextColor(ROOT.kGray+1)
    sectorNum.SetTextFont(0)
    for j in range(19):
        sectorBoundary.DrawLine((j*2*math.pi)/18,hist[0].GetMinimum(),(j*2*math.pi)/18,hist[0].GetMaximum())
        if j < 18 : sectorNum.DrawText(((j+0.5)*2*math.pi)/18,hist[0].GetMaximum()*0.95+hist[0].GetMinimum()*0.05,str(j))
    leg.AddEntry(hist[0],passName)
    leg.AddEntry(myObject,passName+"_old")
    leg.Draw()
    canvas.Draw()
# Out:
# ### hPhiCside
# <div id="root_plot_1699986069321"
#      style="width: 796px; height: 572px">
# </div>
# <script>
#
# function display_root_plot_1699986069321(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":796,"fYtoAbsPixelk":572.00005,"fYtoPixelk":572.00005,"fYtoPixel":-572,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":0.00125628140703518,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00174825174825175,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPad","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.785398221914175,"fY1":18704718.6759986,"fX2":7.06858352909376,"fY2":21255043.7640014,"fXtoAbsPixelk":79.6000547445299,"fXtoPixelk":79.6000547445299,"fXtoPixel":101.349866250688,"fYtoAbsPixelk":4767.19035456223,"fYtoPixelk":4767.19035456223,"fYtoPixel":-2.24285132389903e-4,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":-0.785398221914175,"fPixeltoXk":-0.785398221914175,"fPixeltoX":0.00986681124498484,"fAbsPixeltoYk":21255043.7640014,"fPixeltoYk":18704718.6759986,"fPixeltoY":-4458.6102937112,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":18959751.2,"fUxmax":6.28318530717959,"fUymax":21000011.24,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":18959751.2,"fX2":6.28318530717959,"fY2":21000011.24,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":8,"fName":"hPhiCside","fTitle":"537769 - Azimuthal angle, C side","fLineColor":1,"fLineStyle":1,"fLineWidth":3,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":362,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"xaxis","fTitle":"phi","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":360,"fXmin":0,"fXmax":6.28318530717959,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005, ...

# %%
# %jsroot on
objectName = "hEta"
display(Markdown('### '+objectName))
myObject = findHist(objectName, myHists)
if checkIfExists(rootDataFile,objectName):
    [hist,legend,canvas,pad1] = drawHistograms(objectName,rootDataFile,xAxisRange = [-1.1,1.1])
    
    hist[0].SetTitle(str(runNumber)+" - "+hist[0].GetTitle())
    pad1.cd()
    ROOT.gPad.SetGrid(1)
    leg = ROOT.TLegend()
    myObject.SetLineWidth(3)
    myObject.SetLineColor(ROOT.kRed)
    myObject.Draw("SAME L")
    leg.AddEntry(hist[0],passName)
    leg.AddEntry(myObject,passName+"_old")
    leg.Draw()
    canvas.Draw()
# Out:
# ### hEta
# <div id="root_plot_1699986069438"
#      style="width: 796px; height: 572px">
# </div>
# <script>
#
# function display_root_plot_1699986069438(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":796,"fYtoAbsPixelk":572.00005,"fYtoPixelk":572.00005,"fYtoPixel":-572,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":0.00125628140703518,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00174825174825175,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPad","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-1.3750000204891,"fY1":-15172945.2804725,"fX2":1.3750000204891,"fY2":136556498.480473,"fXtoAbsPixelk":398.00005,"fXtoPixelk":398.00005,"fXtoPixel":289.454541141336,"fYtoAbsPixelk":514.800046590614,"fYtoPixelk":514.800046590614,"fYtoPixel":-3.76986816679567e-6,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":-1.3750000204891,"fPixeltoXk":-1.3750000204891,"fPixeltoX":0.00345477392082688,"fAbsPixeltoYk":136556498.480473,"fPixeltoYk":-15172945.2804725,"fPixeltoY":-265261.265316337,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":-1.1,"fUymin":0,"fUxmax":1.1,"fUymax":121383553.2,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":true,"fGridy":true,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":-1.1,"fY1":0,"fX2":1.1,"fY2":121383553.2,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":8,"fName":"hEta","fTitle":"537769 - Pseudorapidity","fLineColor":1,"fLineStyle":1,"fLineWidth":3,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":402,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":2048,"fName":"xaxis","fTitle":"eta","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":400,"fXmin":-2,"fXmax":2,"fXbins":[],"fFirst":91,"fLast":310,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitl ...
